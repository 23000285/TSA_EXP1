# %%
import pandas as pd

data = pd.read_csv("weatherHistory.csv")

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
data.fillna(method='ffill', inplace=True)
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'], utc=True)
display(data.head())
display(data.isnull().sum())
display(data.info())
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13324\743275998.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  datetime64[ns, UTC]
#  1   Summary                   96453 non-null  object
#  2   Precip Type               96453 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(8), object(3)
# memory usage: 8.8+ MB
# None

# %%
print("Mean Temperature:", data['Temperature (C)'].mean())
print("Mean Apparent Temperature:", data['Apparent Temperature (C)'].mean())
print("Mean Humidity:", data['Humidity'].mean())
print("Mean Wind Speed:", data['Wind Speed (km/h)'].mean())
# Out:
# Mean Temperature: 11.93267843751188
# Mean Apparent Temperature: 10.855028874166694
# Mean Humidity: 0.7348989663359355
# Mean Wind Speed: 10.810640140793963

# %%
data['year'] = data['Formatted Date'].dt.year
data['month'] = data['Formatted Date'].dt.month
data['day'] = data['Formatted Date'].dt.day
data['hour'] = data['Formatted Date'].dt.hour
data['dayofweek'] = data['Formatted Date'].dt.dayofweek

display(data.head())
# Out:
#              Formatted Date        Summary Precip Type  Temperature (C)  \
# 0 2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1 2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2 2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3 2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4 2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary  year  month  day  hour  dayofweek
# 0  Partly cloudy throughout the day.  2006      3   31    22          4
# 1  Partly cloudy throughout the day.  2006      3   31    23          4
# 2  Partly cloudy throughout the day.  2006      4    1     0          5
# 3  Partly cloudy throughout the day.  2006      4    1     1          5
# 4  Partly cloudy throughout the day.  2006      4    1     2          5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data.set_index('Formatted Date', inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(data['Temperature (C)'])
plt.title('Temperature over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (C)')
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(data['Apparent Temperature (C)'])
plt.title('Apparent Temperature over Time')
plt.xlabel('Date')
plt.ylabel('Apparent Temperature (C)')
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(data['Humidity'])
plt.title('Humidity over Time')
plt.xlabel('Date')
plt.ylabel('Humidity')
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(data['Wind Speed (km/h)'])
plt.title('Wind Speed over Time')
plt.xlabel('Date')
plt.ylabel('Wind Speed (km/h)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("weatherHistory.csv")
data['Formatted Date'] = pd.to_datetime(data['Formatted Date'], utc=True)
data.set_index('Formatted Date', inplace=True)

print("Mean Temperature:", data['Temperature (C)'].mean())
print("Mean Apparent Temperature:", data['Apparent Temperature (C)'].mean())
print("Mean Humidity:", data['Humidity'].mean())
print("Mean Wind Speed:", data['Wind Speed (km/h)'].mean())

monthly_avg = data.resample('M').mean(numeric_only=True)
plt.figure(figsize=(12, 6))
plt.plot(monthly_avg['Temperature (C)'])
plt.title('Average Monthly Temperature')
plt.xlabel('Month')
plt.ylabel('Temperature (C)')
plt.show()

yearly_avg = data.resample('Y').mean(numeric_only=True)
plt.figure(figsize=(12, 6))
plt.plot(yearly_avg['Temperature (C)'])
plt.title('Average Yearly Temperature')
plt.xlabel('Year')
plt.ylabel('Temperature (C)')
plt.show()
# Out:
# Mean Temperature: 11.93267843751188
# Mean Apparent Temperature: 10.855028874166694
# Mean Humidity: 0.7348989663359355
# Mean Wind Speed: 10.810640140793963
# C:\Users\admin\AppData\Local\Temp\ipykernel_13324\4111074717.py:13: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_avg = data.resample('M').mean(numeric_only=True)
# C:\Users\admin\AppData\Local\Temp\ipykernel_13324\4111074717.py:21: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_avg = data.resample('Y').mean(numeric_only=True)
